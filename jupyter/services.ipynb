# %%
from dataclasses import dataclass, field
from pathlib import Path
from datetime import datetime
import yaml
import json

# %%
def parse_services_file(file_path: Path):
    """Parse a single .services.yml file."""
    try:
        # Calculate file hash for cache invalidation
        # file_hash = calculate_file_hash(file_path)
            # Add constructors used in Drupal core services.
            # Add constructors used in Drupal core services.
        def construct_ref(loader, node):
            # This simple constructor just returns the value as a string/scalar
            return loader.construct_scalar(node)

        custom_tags = ['!tagged_iterator', '!Ref', '!Sub', '!GetAtt', '!Base64']
        for custom_tag in custom_tags:
            yaml.SafeLoader.add_constructor(custom_tag, construct_ref)
        # Read and parse YAML
        with open(file_path, "r", encoding="utf-8") as f:
            data = yaml.safe_load(f)

        if not data or "services" not in data:
            return

        # Parse each service definition
        for id, service_def in data["services"].items():
            if not isinstance(service_def, dict):
                continue

            # Extract service information
            class_name = service_def.get("class", "")
            arguments = service_def.get("arguments", [])
            tags = service_def.get("tags", [])

            # Create service definition
            if (class_name):
                print(id, class_name, arguments, tags, file_path)
            # self._services[id] = ServiceDefinition(
            #     id=id,
            #     description=class_name,
            #     class_name=class_name,
            #     arguments=arguments,
            #     tags=tags,
            #     file_path=file_path,
            # )

        # Track file info for invalidation
        # self.file_info[file_path] = FileInfo(
        #     path=file_path,
        #     hash=file_hash,
        #     last_modified=datetime.fromtimestamp(file_path.stat().st_mtime),
        # )

    except Exception as e:
        # Log error but don't fail
        print(f"Error parsing {file_path}: {e}")

# %%
base_dirs = ["core", "modules", "profiles", "themes"]

for base_name in base_dirs:
    # Get the actual directory object (e.g., /root/core)
    base_path = Path("/home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web")
    base_path = base_path / base_name

    if not base_path.is_dir():
        continue

    # rglob handles the recursion automatically
    # It will find core/core.services.yml AND core/subdir/other.services.yml
    for services_file in base_path.rglob("core.services.yml"):
        if services_file.is_file():
            parse_services_file(services_file)
# Out:
# plugin.manager.config_action Drupal\Core\Config\Action\ConfigActionManager ['@config.manager', '@config.storage', '@config.typed', '@config.factory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.ip Drupal\Core\Cache\Context\IpCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.protocol_version Drupal\Core\Cache\Context\ProtocolVersionCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.headers Drupal\Core\Cache\Context\HeadersCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.cookies Drupal\Core\Cache\Context\CookiesCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.session Drupal\Core\Cache\Context\SessionCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.session.exists Drupal\Core\Cache\Context\SessionExistsCacheContext ['@session_configuration', '@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.request_format Drupal\Core\Cache\Context\RequestFormatCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url Drupal\Core\Cache\Context\UrlCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.site Drupal\Core\Cache\Context\SiteCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.path Drupal\Core\Cache\Context\PathCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.path.parent Drupal\Core\Cache\Context\PathParentCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.path.is_front Drupal\Core\Cache\Context\IsFrontPathCacheContext ['@path.matcher'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.query_args Drupal\Core\Cache\Context\QueryArgsCacheContext ['@request_stack'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.url.query_args.pagers Drupal\Core\Cache\Context\PagersCacheContext ['@pager.parameters'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.route Drupal\Core\Cache\Context\RouteCacheContext ['@current_route_match'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.route.name Drupal\Core\Cache\Context\RouteNameCacheContext ['@current_route_match'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.route.menu_active_trails Drupal\Core\Cache\Context\MenuActiveTrailsCacheContext ['@menu.active_trail'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.user Drupal\Core\Cache\Context\UserCacheContext ['@current_user'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.user.permissions Drupal\Core\Cache\Context\AccountPermissionsCacheContext ['@current_user', '@user_permissions_hash_generator'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.user.roles Drupal\Core\Cache\Context\UserRolesCacheContext ['@current_user'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.user.is_super_user Drupal\Core\Cache\Context\IsSuperUserCacheContext ['@current_user'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.languages Drupal\Core\Cache\Context\LanguagesCacheContext ['@language_manager'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.theme Drupal\Core\Cache\Context\ThemeCacheContext ['@theme.manager'] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_context.timezone Drupal\Core\Cache\Context\TimeZoneCacheContext [] [{'name': 'cache.context'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_factory Drupal\Core\Cache\CacheFactory ['@settings', '%cache_default_bin_backends%', '%memory_cache_default_bin_backends%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# variation_cache_factory Drupal\Core\Cache\VariationCacheFactory ['@request_stack', '@cache_factory', '@cache_contexts_manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_contexts_manager Drupal\Core\Cache\Context\CacheContextsManager ['@service_container', '%cache_contexts%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_tags.invalidator Drupal\Core\Cache\CacheTagsInvalidator [] [{'name': 'service_collector', 'call': 'addInvalidator', 'tag': 'cache_tags_invalidator'}, {'name': 'service_collector', 'call': 'addBin', 'tag': 'cache.bin'}, {'name': 'service_collector', 'call': 'addBin', 'tag': 'cache.bin.memory'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_tags.invalidator.checksum Drupal\Core\Cache\DatabaseCacheTagsChecksum ['@database'] [{'name': 'cache_tags_invalidator'}, {'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_tags.preloader Drupal\Core\Cache\EventSubscriber\CacheTagPreloadSubscriber [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.chainedfast Drupal\Core\Cache\ChainedFastBackendFactory ['@settings'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.database Drupal\Core\Cache\DatabaseBackendFactory ['@database', '@cache_tags.invalidator.checksum', '@settings', '@serialization.phpserialize', '@datetime.time'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.apcu Drupal\Core\Cache\ApcuBackendFactory ['%app.root%', '%site.path%', '@cache_tags.invalidator.checksum', '@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.php Drupal\Core\Cache\PhpBackendFactory ['@cache_tags.invalidator.checksum', '@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.memory Drupal\Core\Cache\MemoryBackendFactory ['@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.backend.memory.memory Drupal\Core\Cache\MemoryCache\MemoryCacheFactory ['@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.static Drupal\Core\Cache\CacheBackendInterface ['static'] [{'name': 'cache.bin', 'default_backend': 'cache.backend.memory'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.bootstrap Drupal\Core\Cache\CacheBackendInterface ['bootstrap'] [{'name': 'cache.bin', 'default_backend': 'cache.backend.chainedfast'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.config Drupal\Core\Cache\CacheBackendInterface ['config'] [{'name': 'cache.bin', 'default_backend': 'cache.backend.chainedfast'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.default Drupal\Core\Cache\CacheBackendInterface ['default'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.entity Drupal\Core\Cache\CacheBackendInterface ['entity'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.menu Drupal\Core\Cache\CacheBackendInterface ['menu'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.render Drupal\Core\Cache\CacheBackendInterface ['render'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.access_policy Drupal\Core\Cache\CacheBackendInterface ['access_policy'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.access_policy_memory Drupal\Core\Cache\CacheBackendInterface ['access_policy_memory'] [{'name': 'cache.bin.memory', 'default_backend': 'cache.backend.memory.memory'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.data Drupal\Core\Cache\CacheBackendInterface ['data'] [{'name': 'cache.bin'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache.discovery Drupal\Core\Cache\CacheBackendInterface ['discovery'] [{'name': 'cache.bin', 'default_backend': 'cache.backend.chainedfast'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_prewarmer Drupal\Core\PreWarm\CachePreWarmer ['@class_resolver'] [{'name': 'service_id_collector', 'tag': 'cache_prewarmable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# variation_cache.access_policy Drupal\Core\Cache\VariationCacheInterface ['access_policy'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# variation_cache.access_policy_memory Drupal\Core\Cache\VariationCacheInterface ['access_policy_memory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# asset.query_string Drupal\Core\Asset\AssetQueryString ['@state', '@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cache_router_rebuild_subscriber Drupal\Core\EventSubscriber\CacheRouterRebuildSubscriber [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# page_cache_request_policy Drupal\Core\PageCache\DefaultRequestPolicy ['@session_configuration'] [{'name': 'service_collector', 'tag': 'page_cache_request_policy', 'call': 'addPolicy'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# page_cache_response_policy Drupal\Core\PageCache\ChainResponsePolicy [] [{'name': 'service_collector', 'tag': 'page_cache_response_policy', 'call': 'addPolicy'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# page_cache_kill_switch Drupal\Core\PageCache\ResponsePolicy\KillSwitch [] [{'name': 'page_cache_response_policy'}, {'name': 'dynamic_page_cache_response_policy'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# page_cache_no_cache_routes Drupal\Core\PageCache\ResponsePolicy\DenyNoCacheRoutes ['@current_route_match'] [{'name': 'page_cache_response_policy'}, {'name': 'dynamic_page_cache_response_policy'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# page_cache_no_server_error Drupal\Core\PageCache\ResponsePolicy\NoServerError [] [{'name': 'page_cache_response_policy'}, {'name': 'dynamic_page_cache_response_policy'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.manager Drupal\Core\Config\ConfigManager ['@entity_type.manager', '@config.factory', '@config.typed', '@string_translation', '@config.storage', '@event_dispatcher', '@entity.repository', '@extension.path.resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.factory Drupal\Core\Config\ConfigFactory ['@config.storage', '@event_dispatcher', '@config.typed'] [{'name': 'service_collector', 'tag': 'config.factory.override', 'call': 'addOverride'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.importer_subscriber Drupal\Core\Config\Importer\FinalMissingContentSubscriber [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.installer Drupal\Core\Config\ConfigInstaller ['@config.factory', '@config.storage', '@config.typed', '@config.manager', '@event_dispatcher', '%install_profile%', '@extension.path.resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage Drupal\Core\Config\CachedStorage ['@config.storage.active', '@cache.config'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.active Drupal\Core\Config\DatabaseStorage ['@database', 'config'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.checkpoint Drupal\Core\Config\Checkpoint\CheckpointStorage ['@config.storage', '@config.checkpoints', '@keyvalue'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.checkpoints Drupal\Core\Config\Checkpoint\LinearHistory ['@state', '@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.import_transformer Drupal\Core\Config\ImportStorageTransformer ['@event_dispatcher', '@database', '@lock', '@lock.persistent'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.export Drupal\Core\Config\ManagedStorage ['@config.storage.export.manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.export.manager Drupal\Core\Config\ExportStorageManager ['@config.storage', '@database', '@event_dispatcher', '@lock'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.sync Drupal\Core\Config\FileStorage [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.snapshot Drupal\Core\Config\DatabaseStorage ['@database', 'config_snapshot'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.storage.schema Drupal\Core\Config\ExtensionInstallStorage ['@config.storage', 'config/schema', '', True, '%install_profile%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# config.typed Drupal\Core\Config\TypedConfigManager ['@config.storage', '@config.storage.schema', '@cache.discovery', '@module_handler', '@class_resolver'] [{'name': 'plugin_manager_cache_clear'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# context.handler Drupal\Core\Plugin\Context\ContextHandler [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# context.repository Drupal\Core\Plugin\Context\LazyContextRepository ['@service_container'] [{'name': 'service_id_collector', 'tag': 'context_provider'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# cron Drupal\Core\Cron ['@module_handler', '@lock', '@queue', '@state', '@account_switcher', '@logger.channel.cron', '@plugin.manager.queue_worker', '@datetime.time', '%queue.config%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# diff.formatter Drupal\Core\Diff\DiffFormatter ['@config.factory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# database Drupal\Core\Database\Connection ['default'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# database.replica Drupal\Core\Database\Connection ['replica'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# database.replica_kill_switch Drupal\Core\Database\ReplicaKillSwitch ['@settings', '@datetime.time', '@session'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# datetime.time Drupal\Component\Datetime\Time ['@request_stack'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# file_system Drupal\Core\File\FileSystem ['@stream_wrapper_manager', '@settings'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# file_url_generator Drupal\Core\File\FileUrlGenerator ['@stream_wrapper_manager', '@request_stack', '@module_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# form_builder Drupal\Core\Form\FormBuilder ['@form_validator', '@form_submitter', '@form_cache', '@module_handler', '@event_dispatcher', '@request_stack', '@class_resolver', '@element_info', '@theme.manager', '@?csrf_token'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# form_validator Drupal\Core\Form\FormValidator ['@request_stack', '@string_translation', '@csrf_token', '@logger.channel.form', '@form_error_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# form_submitter Drupal\Core\Form\FormSubmitter ['@request_stack', '@url_generator', '@redirect_response_subscriber'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# form_error_handler Drupal\Core\Form\FormErrorHandler [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# form_cache Drupal\Core\Form\FormCache ['%app.root%', '@keyvalue.expirable', '@module_handler', '@current_user', '@csrf_token', '@logger.channel.form', '@request_stack', '@page_cache_request_policy'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# keyvalue Drupal\Core\KeyValueStore\KeyValueFactory ['@service_container', '%factory.keyvalue%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# keyvalue.database Drupal\Core\KeyValueStore\KeyValueDatabaseFactory ['@serialization.phpserialize', '@database'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# keyvalue.expirable Drupal\Core\KeyValueStore\KeyValueExpirableFactory ['@service_container', '%factory.keyvalue.expirable%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# keyvalue.expirable.database Drupal\Core\KeyValueStore\KeyValueDatabaseExpirableFactory ['@serialization.phpserialize', '@database', '@datetime.time'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# logger.factory Drupal\Core\Logger\LoggerChannelFactory ['@request_stack', '@current_user'] [{'name': 'service_collector', 'tag': 'logger', 'call': 'addLogger'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# logger.channel_base Drupal\Core\Logger\LoggerChannel [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# logger.channel.file Drupal\Core\Logger\LoggerChannel ['file'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# logger.log_message_parser Drupal\Core\Logger\LogMessageParser [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# serialization.json Drupal\Component\Serialization\Json [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# serialization.phpserialize Drupal\Component\Serialization\PhpSerialize [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# serialization.yaml Drupal\Component\Serialization\Yaml [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# settings Drupal\Core\Site\Settings [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# state Drupal\Core\State\State ['@keyvalue', '@cache.bootstrap', '@lock'] [{'name': 'needs_destruction'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# queue Drupal\Core\Queue\QueueFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# queue.database Drupal\Core\Queue\QueueDatabaseFactory ['@database'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# path.current Drupal\Core\Path\CurrentPathStack ['@request_stack'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_handler_stack GuzzleHttp\HandlerStack [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_handler_stack_configurator Drupal\Core\Http\HandlerStackConfigurator ['@service_container'] [{'name': 'service_id_collector', 'tag': 'http_client_middleware'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_client GuzzleHttp\Client [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_client_factory Drupal\Core\Http\ClientFactory ['@http_handler_stack'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.link_relation_type \Drupal\Core\Http\LinkRelationTypeManager ['%app.root%', '@module_handler', '@cache.discovery'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# theme.negotiator Drupal\Core\Theme\ThemeNegotiator ['@access_check.theme', '@class_resolver'] [{'name': 'service_id_collector', 'tag': 'theme_negotiator'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# theme.negotiator.default Drupal\Core\Theme\DefaultNegotiator ['@config.factory'] [{'name': 'theme_negotiator', 'priority': -100}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# theme.negotiator.ajax_base_page Drupal\Core\Theme\AjaxBasePageNegotiator ['@csrf_token', '@config.factory', '@request_stack'] [{'name': 'theme_negotiator', 'priority': 1000}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# container.namespaces ArrayObject ['%container.namespaces%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# module_handler Drupal\Core\Extension\ModuleHandler ['%app.root%', '%container.modules%', '@event_dispatcher', '%hook_implementations_map%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# module_installer Drupal\Core\Extension\ModuleInstaller [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# module_installer.uninstall_validators \IteratorIterator ['module_install.uninstall_validator'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.list.module Drupal\Core\Extension\ModuleExtensionList ['%app.root%', 'module', '@cache.default', '@info_parser', '@module_handler', '@state', '@config.factory', '@extension.list.profile', '%install_profile%', '%container.modules%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.list.profile Drupal\Core\Extension\ProfileExtensionList ['%app.root%', 'profile', '@cache.default', '@info_parser', '@module_handler', '@state', '%install_profile%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.list.theme Drupal\Core\Extension\ThemeExtensionList ['%app.root%', 'theme', '@cache.bootstrap', '@info_parser', '@module_handler', '@state', '@config.factory', '@extension.list.theme_engine', '%install_profile%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.list.theme_engine Drupal\Core\Extension\ThemeEngineExtensionList ['%app.root%', 'theme_engine', '@cache.default', '@info_parser', '@module_handler', '@state', '%install_profile%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.list.database_driver Drupal\Core\Extension\DatabaseDriverList ['%app.root%', 'database_driver', '@cache.default'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# extension.path.resolver Drupal\Core\Extension\ExtensionPathResolver ['@extension.list.module', '@extension.list.profile', '@extension.list.theme', '@extension.list.theme_engine'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# content_uninstall_validator Drupal\Core\Entity\ContentUninstallValidator ['@entity_type.manager', '@string_translation'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# required_module_uninstall_validator Drupal\Core\Extension\RequiredModuleUninstallValidator ['@string_translation', '@extension.list.module'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# module_required_by_themes_uninstall_validator Drupal\Core\Extension\ModuleRequiredByThemesUninstallValidator ['@string_translation', '@extension.list.module', '@extension.list.theme'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# database_driver_uninstall_validator Drupal\Core\Extension\DatabaseDriverUninstallValidator ['@string_translation', '@extension.list.module', '@database'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# install_profile_uninstall_validator Drupal\Core\Extension\InstallProfileUninstallValidator ['@string_translation', '@extension.list.module', '@extension.list.theme', '%install_profile%', '%app.root%', '%site.path%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# theme_handler Drupal\Core\Extension\ThemeHandler ['%app.root%', '@config.factory', '@extension.list.theme'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# theme_installer Drupal\Core\Extension\ThemeInstaller ['@theme_handler', '@config.factory', '@config.installer', '@module_handler', '@config.manager', '@asset.css.collection_optimizer', '@router.builder', '@logger.channel.default', '@state', '@extension.list.module', '@theme.registry', '@extension.list.theme', '@plugin.manager.sdc'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.memory_cache Drupal\Core\Cache\MemoryCache\LruMemoryCache ['@datetime.time', '%entity.memory_cache.slots%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_type.manager Drupal\Core\Entity\EntityTypeManager ['@container.namespaces', '@module_handler', '@cache.discovery', '@string_translation', '@class_resolver', '@entity.last_installed_schema.repository', '@service_container'] [{'name': 'plugin_manager_cache_clear'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_type.repository Drupal\Core\Entity\EntityTypeRepository ['@entity_type.manager', '@entity_type.bundle.info'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_type.bundle.info Drupal\Core\Entity\EntityTypeBundleInfo ['@entity_type.manager', '@language_manager', '@module_handler', '@typed_data_manager', '@cache.discovery'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.repository Drupal\Core\Entity\EntityRepository ['@entity_type.manager', '@language_manager', '@context.repository'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_display.repository Drupal\Core\Entity\EntityDisplayRepository ['@entity_type.manager', '@module_handler', '@cache.discovery', '@language_manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_field.manager Drupal\Core\Entity\EntityFieldManager ['@entity_type.manager', '@entity_type.bundle.info', '@entity_display.repository', '@typed_data_manager', '@language_manager', '@keyvalue', '@module_handler', '@cache.discovery', '@entity.last_installed_schema.repository'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_type.listener Drupal\Core\Entity\EntityTypeListener ['@entity_type.manager', '@entity_field.manager', '@event_dispatcher', '@entity.last_installed_schema.repository'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_bundle.listener Drupal\Core\Entity\EntityBundleListener ['@entity_type.manager', '@entity_type.bundle.info', '@entity_field.manager', '@module_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_route_subscriber Drupal\Core\EventSubscriber\EntityRouteProviderSubscriber ['@entity_type.manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.definition_update_manager Drupal\Core\Entity\EntityDefinitionUpdateManager ['@entity_type.manager', '@entity.last_installed_schema.repository', '@entity_field.manager', '@entity_type.listener', '@field_storage_definition.listener'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.last_installed_schema.repository Drupal\Core\Entity\EntityLastInstalledSchemaRepository ['@keyvalue', '@cache.discovery'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity_field.deleted_fields_repository Drupal\Core\Field\DeletedFieldsRepository ['@state'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# field_storage_definition.listener Drupal\Core\Field\FieldStorageDefinitionListener ['@entity_type.manager', '@event_dispatcher', '@entity.last_installed_schema.repository', '@entity_field.manager', '@entity_field.deleted_fields_repository'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# field_definition.listener Drupal\Core\Field\FieldDefinitionListener ['@entity_type.manager', '@entity_field.manager', '@keyvalue', '@cache.discovery'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.form_builder Drupal\Core\Entity\EntityFormBuilder ['@entity_type.manager', '@form_builder'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.bundle_config_import_validator Drupal\Core\Entity\Event\BundleConfigImportValidate ['@config.manager', '@entity_type.manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# entity.autocomplete_matcher Drupal\Core\Entity\EntityAutocompleteMatcher ['@plugin.manager.entity_reference_selection'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin_form.factory Drupal\Core\Plugin\PluginFormFactory ['@class_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.entity_reference_selection Drupal\Core\Entity\EntityReferenceSelection\SelectionPluginManager [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.block Drupal\Core\Block\BlockManager ['@logger.channel.default'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.field.field_type Drupal\Core\Field\FieldTypePluginManager ['@container.namespaces', '@cache.discovery', '@module_handler', '@typed_data_manager', '@plugin.manager.field.field_type_category'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.field.field_type_category \Drupal\Core\Field\FieldTypeCategoryManager ['%app.root%', '@module_handler', '@cache.discovery'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.field.widget Drupal\Core\Field\WidgetPluginManager ['@container.namespaces', '@cache.discovery', '@module_handler', '@plugin.manager.field.field_type'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.field.formatter Drupal\Core\Field\FormatterPluginManager ['@container.namespaces', '@cache.discovery', '@module_handler', '@plugin.manager.field.field_type'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.archiver Drupal\Core\Archiver\ArchiverManager ['@file_system'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.action Drupal\Core\Action\ActionManager ['@container.namespaces', '@cache.discovery', '@module_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.menu.link Drupal\Core\Menu\MenuLinkManager ['@menu.tree_storage', '@menu_link.static.overrides', '@module_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu.link_tree Drupal\Core\Menu\MenuLinkTree ['@menu.tree_storage', '@plugin.manager.menu.link', '@router.route_provider', '@menu.active_trail', '@callable_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu.default_tree_manipulators Drupal\Core\Menu\DefaultMenuLinkTreeManipulators ['@access_manager', '@current_user', '@entity_type.manager', '@module_handler'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu.active_trail Drupal\Core\Menu\MenuActiveTrail ['@plugin.manager.menu.link', '@current_route_match', '@cache.menu', '@lock', '@path.matcher'] [{'name': 'needs_destruction'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu.parent_form_selector Drupal\Core\Menu\MenuParentFormSelector ['@menu.link_tree', '@entity_type.manager', '@string_translation'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.menu.local_action Drupal\Core\Menu\LocalActionManager ['@http_kernel.controller.argument_resolver', '@request_stack', '@current_route_match', '@router.route_provider', '@module_handler', '@cache.discovery', '@language_manager', '@access_manager', '@current_user'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.menu.local_task Drupal\Core\Menu\LocalTaskManager ['@http_kernel.controller.argument_resolver', '@request_stack', '@current_route_match', '@router.route_provider', '@module_handler', '@cache.discovery', '@language_manager', '@access_manager', '@current_user'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.menu.contextual_link Drupal\Core\Menu\ContextualLinkManager ['@controller_resolver', '@module_handler', '@cache.discovery', '@language_manager', '@access_manager', '@current_user', '@request_stack'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.display_variant Drupal\Core\Display\VariantManager [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.manager.queue_worker Drupal\Core\Queue\QueueWorkerManager [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# plugin.cache_clearer Drupal\Core\Plugin\CachedDiscoveryClearer [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# paramconverter.menu_link Drupal\Core\ParamConverter\MenuLinkPluginConverter ['@plugin.manager.menu.link'] [{'name': 'paramconverter'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu.tree_storage Drupal\Core\Menu\MenuTreeStorage ['@database', '@cache.menu', '@cache_tags.invalidator', 'menu_tree'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# menu_link.static.overrides Drupal\Core\Menu\StaticMenuLinkOverrides ['@config.factory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# request_stack Symfony\Component\HttpFoundation\RequestStack [] [{'name': 'persist'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# current_route_match Drupal\Core\Routing\CurrentRouteMatch ['@request_stack'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# event_dispatcher Symfony\Component\EventDispatcher\EventDispatcher [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# controller_resolver Drupal\Core\Controller\ControllerResolver ['@callable_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# class_resolver Drupal\Core\DependencyInjection\ClassResolver ['@service_container'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# callable_resolver Drupal\Core\Utility\CallableResolver ['@class_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# title_resolver Drupal\Core\Controller\TitleResolver ['@controller_resolver', '@string_translation', '@http_kernel.controller.argument_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_kernel Drupal\Core\StackMiddleware\StackedHttpKernel [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_kernel.basic Symfony\Component\HttpKernel\HttpKernel ['@event_dispatcher', '@controller_resolver', '@request_stack', '@http_kernel.controller.argument_resolver', True] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_kernel.controller.argument_resolver Symfony\Component\HttpKernel\Controller\ArgumentResolver ['@http_kernel.controller.argument_metadata_factory', ['@argument_resolver.request_attribute', '@argument_resolver.request', '@argument_resolver.psr7_request', '@argument_resolver.route_match', '@argument_resolver.default']] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_kernel.controller.argument_metadata_factory Symfony\Component\HttpKernel\ControllerMetadata\ArgumentMetadataFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# argument_resolver.request_attribute Symfony\Component\HttpKernel\Controller\ArgumentResolver\RequestAttributeValueResolver [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# argument_resolver.request Symfony\Component\HttpKernel\Controller\ArgumentResolver\RequestValueResolver [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# argument_resolver.psr7_request Drupal\Core\Controller\ArgumentResolver\Psr7RequestValueResolver ['@psr7.http_message_factory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# argument_resolver.route_match Drupal\Core\Controller\ArgumentResolver\RouteMatchValueResolver [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# argument_resolver.default Symfony\Component\HttpKernel\Controller\ArgumentResolver\DefaultValueResolver [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.content_length Drupal\Core\StackMiddleware\ContentLength [] [{'name': 'http_middleware', 'priority': 140}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.ajax_page_state Drupal\Core\StackMiddleware\AjaxPageState [] [{'name': 'http_middleware', 'priority': 500}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.negotiation Drupal\Core\StackMiddleware\NegotiationMiddleware [] [{'name': 'http_middleware', 'priority': 400}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.reverse_proxy Drupal\Core\StackMiddleware\ReverseProxyMiddleware ['@settings'] [{'name': 'http_middleware', 'priority': 300}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.kernel_pre_handle Drupal\Core\StackMiddleware\KernelPreHandle ['@kernel'] [{'name': 'http_middleware', 'priority': 100}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.session Drupal\Core\StackMiddleware\Session [] [{'name': 'http_middleware', 'priority': 50}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# http_middleware.cors Asm89\Stack\Cors ['%cors.config%'] [{'name': 'http_middleware', 'priority': 250}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr7.http_foundation_factory Symfony\Bridge\PsrHttpMessage\Factory\HttpFoundationFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr17.server_request_factory GuzzleHttp\Psr7\HttpFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr17.stream_factory GuzzleHttp\Psr7\HttpFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr17.uploaded_file_factory GuzzleHttp\Psr7\HttpFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr17.response_factory GuzzleHttp\Psr7\HttpFactory [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# psr7.http_message_factory Symfony\Bridge\PsrHttpMessage\Factory\PsrHttpFactory ['@psr17.server_request_factory', '@psr17.stream_factory', '@psr17.uploaded_file_factory', '@psr17.response_factory'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# language_manager Drupal\Core\Language\LanguageManager ['@language.default'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# language.current_language_context Drupal\Core\Language\ContextProvider\CurrentLanguageContext ['@language_manager'] [{'name': 'context_provider'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# language.default Drupal\Core\Language\LanguageDefault ['%language.default_values%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# string_translator.custom_strings Drupal\Core\StringTranslation\Translator\CustomStrings ['@settings'] [{'name': 'string_translator', 'priority': 30}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# string_translation Drupal\Core\StringTranslation\TranslationManager ['@language.default'] [{'name': 'service_collector', 'tag': 'string_translator', 'call': 'addTranslator'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# typed_data_manager Drupal\Core\TypedData\TypedDataManager ['@container.namespaces', '@cache.discovery', '@module_handler', '@class_resolver'] [{'name': 'plugin_manager_cache_clear'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# validation.constraint Drupal\Core\Validation\ConstraintManager [] [{'name': 'plugin_manager_cache_clear'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# validation.basic_recursive_validator_factory Drupal\Core\Validation\BasicRecursiveValidatorFactory ['@class_resolver'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# lock Drupal\Core\Lock\DatabaseLockBackend ['@database'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# lock.persistent Drupal\Core\Lock\PersistentDatabaseLockBackend ['@database'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.request_context Drupal\Core\Routing\RequestContext [] [{'name': 'persist'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.admin_context Drupal\Core\Routing\AdminContext ['@current_route_match'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.route_provider Drupal\Core\Routing\RouteProvider ['@database', '@state', '@path.current', '@cache.data', '@path_processor_manager', '@cache_tags.invalidator', 'router', '@language_manager'] [{'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.route_provider.lazy_builder Drupal\Core\Routing\RouteProviderLazyBuilder ['@router.route_provider', '@router.builder'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.route_preloader Drupal\Core\Routing\RoutePreloader ['@router.route_provider', '@state'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# url_generator.non_bubbling Drupal\Core\Routing\UrlGenerator ['@router.route_provider', '@path_processor_manager', '@route_processor_manager', '@request_stack', '%filter_protocols%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# url_generator Drupal\Core\Render\MetadataBubblingUrlGenerator ['@url_generator.non_bubbling', '@renderer'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# redirect.destination Drupal\Core\Routing\RedirectDestination ['@request_stack', '@url_generator'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# unrouted_url_assembler Drupal\Core\Utility\UnroutedUrlAssembler ['@request_stack', '@path_processor_manager', '%filter_protocols%'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# link_generator Drupal\Core\Utility\LinkGenerator ['@url_generator', '@module_handler', '@renderer'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router Drupal\Core\Routing\AccessAwareRouter ['@router.no_access_checks', '@access_manager', '@current_user'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# router.no_access_checks \Drupal\Core\Routing\Router ['@router.route_provider', '@path.current', '@url_generator'] [{'name': 'service_collector', 'tag': 'route_enhancer', 'call': 'addRouteEnhancer'}, {'name': 'service_collector', 'tag': 'route_filter', 'call': 'addRouteFilter'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/core/core.services.yml
# ...
# redirect_domain.request_subscriber Drupal\redirect_domain\EventSubscriber\DomainRedirectRequestSubscriber ['@config.factory', '@redirect.checker', '@path.matcher'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/redirect/modules/redirect_domain/redirect_domain.services.yml
# actions_permissions.views_bulk_operations_actions Drupal\actions_permissions\EventSubscriber\ActionsPermissionsEventSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/views_bulk_operations/modules/actions_permissions/actions_permissions.services.yml
# search_api_solr_test.search_api_subscriber Drupal\search_api_solr_test\EventSubscriber\SearchApiSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/tests/modules/search_api_solr_test/search_api_solr_test.services.yml
# logger.solr Drupal\search_api_solr_log\Logger\SolrLogger ['@logger.log_message_parser', '@solarium.query_helper'] [{'name': 'logger'}, {'name': 'backend_overridable'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_log/search_api_solr_log.services.yml
# search_api_solr_log.kernel_subscriber Drupal\search_api_solr_log\EventSubscriber\EventSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_log/search_api_solr_log.services.yml
# search_api_solr_admin.commands Drupal\search_api_solr_admin\Commands\SearchApiSolrAdminCommands ['@search_api_solr_admin.command_helper'] [{'name': 'drush.command'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_admin/drush.services.yml
# access_check.search_api_solr_admin Drupal\search_api_solr_admin\Access\SolrAdminAccessCheck ['@current_user'] [{'name': 'access_check', 'applies_to': '_search_api_solr_admin_access_check'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_admin/search_api_solr_admin.services.yml
# access_check.search_api_solr_admin_cloud Drupal\search_api_solr_admin\Access\SolrAdminCloudAccessCheck ['@current_user'] [{'name': 'access_check', 'applies_to': '_search_api_solr_admin_cloud_access_check'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_admin/search_api_solr_admin.services.yml
# access_check.search_api_solr_admin_trusted_context_supported Drupal\search_api_solr_admin\Access\SolrAdminTrustedContextSupportedAccessCheck ['@current_user'] [{'name': 'access_check', 'applies_to': '_search_api_solr_admin_trusted_context_supported_access_check'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_admin/search_api_solr_admin.services.yml
# search_api_solr_admin.command_helper Drupal\search_api_solr_admin\Utility\SolrAdminCommandHelper ['@entity_type.manager', '@module_handler', '@event_dispatcher', '@search_api_solr.configset_controller', '@file_system', '@messenger'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_admin/search_api_solr_admin.services.yml
# search_api_solr_legacy.search_api_solr_subscriber Drupal\search_api_solr_legacy\EventSubscriber\SearchApiSolrSubscriber ['@extension.list.module'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_legacy/search_api_solr_legacy.services.yml
# search_api_solr_devel.route_subscriber Drupal\search_api_solr_devel\Routing\DevelRouteSubscriber ['@entity_type.manager'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_devel/search_api_solr_devel.services.yml
# search_api_solr_devel.solarium_request_logger Drupal\search_api_solr_devel\Logging\SolariumRequestLogger ['@devel.dumper'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_solr/modules/search_api_solr_devel/search_api_solr_devel.services.yml
# smart_date_recur.manager Drupal\smart_date_recur\SmartDateRecurManager [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/smart_date/modules/smart_date_recur/smart_date_recur.services.yml
# pantheon_advanced_page_cache_test.cacheable_response_subscriber Drupal\pantheon_advanced_page_cache_test\EventSubscriber\CacheableResponseSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/pantheon_advanced_page_cache/modules/pantheon_advanced_page_cache_test/pantheon_advanced_page_cache_test.services.yml
# simple_oauth_test.route_subscriber Drupal\simple_oauth_test\Routing\SimpleOauthTestRouteSubscriber [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_oauth/tests/modules/simple_oauth_test/simple_oauth_test.services.yml
# plugin.manager.oauth2_scope Drupal\simple_oauth_static_scope\Plugin\Oauth2ScopeManager ['@module_handler', '@cache.discovery', '@language_manager', '@plugin.manager.scope_granularity', '@plugin.manager.oauth2_grant.processor'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_oauth/modules/simple_oauth_static_scope/simple_oauth_static_scope.services.yml
# webform_submission_export_import.importer Drupal\webform_submission_export_import\WebformSubmissionExportImportImporter ['@config.factory', '@logger.factory', '@entity_type.manager', '@plugin.manager.webform.element', '@file_system'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_export_import/webform_submission_export_import.services.yml
# webform_submission_export_import.route_subscriber Drupal\webform_submission_export_import\Routing\WebformSubmissionExportImportRouteSubscriber ['@module_handler'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_export_import/webform_submission_export_import.services.yml
# logger.channel.webform_submission_export_import Drupal\Core\Logger\LoggerChannel ['webform_submission_export_import'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_export_import/webform_submission_export_import.services.yml
# webform_scheduled_email.manager.commands \Drupal\webform_scheduled_email\Commands\WebformScheduledEmailCommands ['@webform_scheduled_email.manager'] [{'name': 'drush.command'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_scheduled_email/drush.services.yml
# webform_scheduled_email.manager Drupal\webform_scheduled_email\WebformScheduledEmailManager ['@datetime.time', '@database', '@language_manager', '@config.factory', '@logger.factory', '@entity_type.manager', '@webform.token_manager', '@webform.entity_reference_manager'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_scheduled_email/webform_scheduled_email.services.yml
# webform_submission_log.manager Drupal\webform_submission_log\WebformSubmissionLogManager ['@database'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_log/webform_submission_log.services.yml
# logger.webform_submission_log Drupal\webform_submission_log\WebformSubmissionLogLogger ['@logger.log_message_parser', '@webform_submission_log.manager'] [{'name': 'logger'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_log/webform_submission_log.services.yml
# webform_submission_log.route_subscriber Drupal\webform_submission_log\Routing\WebformSubmissionLogRouteSubscriber ['@module_handler'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_submission_log/webform_submission_log.services.yml
# webform_access.breadcrumb Drupal\webform_access\Breadcrumb\WebformAccessBreadcrumbBuilder ['@string_translation'] [{'name': 'breadcrumb_builder', 'priority': 1003}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_access/webform_access.services.yml
# webform_ui.path_processor Drupal\webform_ui\PathProcessor\WebformUiPathProcessor [] [{'name': 'path_processor_outbound'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_ui/webform_ui.services.yml
# webform_devel.commands \Drupal\webform_devel\Commands\WebformDevelCommands ['@file_system', '@state', '@user.data', '@module_handler'] [{'name': 'drush.command'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_devel/drush.services.yml
# webform_options_limit.route_subscriber Drupal\webform_options_limit\Routing\WebformOptionsLimitRouteSubscriber ['@module_handler'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_options_limit/webform_options_limit.services.yml
# webform_entity_print.print_css_alter_subscriber Drupal\webform_entity_print\EventSubscriber\WebformEntityPrintCssAlterSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_entity_print/webform_entity_print.services.yml
# webform_entity_print.request_subscriber Drupal\webform_entity_print\EventSubscriber\WebformEntityPrintRequestSubscriber ['@current_route_match'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_entity_print/webform_entity_print.services.yml
# webform_cards.manager Drupal\webform_cards\WebformCardsManager ['@plugin.manager.webform.element', '@webform_submission.conditions_validator'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_cards/webform_cards.services.yml
# webform_cards.route_subscriber Drupal\webform_cards\Routing\WebformCardsRouteSubscriber ['@module_handler'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_cards/webform_cards.services.yml
# webform_schema.manager Drupal\webform_schema\WebformSchemaManager ['@plugin.manager.element_info', '@entity_field.manager', '@plugin.manager.webform.element'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_schema/webform_schema.services.yml
# webform_node.uninstall_validator Drupal\webform_node\WebformNodeUninstallValidator ['@entity_type.manager', '@string_translation'] [{'name': 'module_install.uninstall_validator'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_node/webform_node.services.yml
# webform_share.event_subscriber Drupal\webform_share\EventSubscriber\WebformShareEventSubscriber ['@current_route_match'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_share/webform_share.services.yml
# webform_share.page_display_variant_subscriber Drupal\webform_share\EventSubscriber\WebformShareDisplayVariantSubscriber ['@current_route_match'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_share/webform_share.services.yml
# webform_share.route_subscriber Drupal\webform_share\Routing\WebformShareRouteSubscriber ['@module_handler'] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_share/webform_share.services.yml
# webform_share.theme_negotiator Drupal\webform_share\Theme\WebformShareThemeNegotiator ['@config.factory'] [{'name': 'theme_negotiator'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/webform/modules/webform_share/webform_share.services.yml
# symfony_mailer.test Drupal\symfony_mailer_test\MailerTestService ['@state'] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/symfony_mailer/tests/modules/symfony_mailer_test/symfony_mailer_test.services.yml
# simple_sitemap.views Drupal\simple_sitemap_views\SimpleSitemapViews [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_views/simple_sitemap_views.services.yml
# simple_sitemap.views.argument_collector Drupal\simple_sitemap_views\EventSubscriber\ArgumentCollector [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_views/simple_sitemap_views.services.yml
# simple_sitemap.engines.sitemap_submitter Drupal\simple_sitemap_engines\Submitter\SitemapSubmitter [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_engines/simple_sitemap_engines.services.yml
# simple_sitemap.engines.index_now_submitter Drupal\simple_sitemap_engines\Submitter\IndexNowSubmitter [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_engines/simple_sitemap_engines.services.yml
# simple_sitemap.engines.form_helper Drupal\simple_sitemap_engines\Form\FormHelper [] [] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_engines/simple_sitemap_engines.services.yml
# simple_sitemap.engines.path_processor Drupal\simple_sitemap_engines\PathProcessor\IndexNowPathProcessor [] [{'name': 'path_processor_inbound', 'priority': 300}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/simple_sitemap/modules/simple_sitemap_engines/simple_sitemap_engines.services.yml
# access_check.search_api_pantheon_admin Drupal\search_api_pantheon_admin\Access\AdminAccessCheck ['@current_user'] [{'name': 'access_check', 'applies_to': '_search_api_pantheon_admin_access_check'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/search_api_pantheon/modules/search_api_pantheon_admin/search_api_pantheon_admin.services.yml
# acquia_connector_test.client_middleware Drupal\acquia_connector_test\AcquiaConnectorMiddleware ['@state'] [{'name': 'http_client_middleware'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/acquia_connector/tests/modules/acquia_connector_test/acquia_connector_test.services.yml
# acquia_connector_subdata_test.subscription_data Drupal\acquia_connector_subdata_test\EventSubscriber\AcquiaSubscriptionData\SubscriptionData [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/acquia_connector/tests/modules/acquia_connector_subdata_test/acquia_connector_subdata_test.services.yml
# address_test.event_subscriber Drupal\address_test\EventSubscriber\AddressTestEventSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/address/tests/modules/address_test/address_test.services.yml
# address_test.great_britain_subscriber Drupal\address_test\EventSubscriber\GreatBritainEventSubscriber [] [{'name': 'event_subscriber'}] /home/yuri/ssd2/project-files/Kalamuna/projects/mtcno/mtcno/web/modules/contrib/address/tests/modules/address_test/address_test.services.yml
